# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.evaluation import evaluate_policy
import pygame
from gymnasium import spaces
import random

# %%
class SnakeEnv(gym.Env):
    metadata = {'render_modes': ['human', 'rgb_array'], 'render_fps': 4}

    def __init__(self, grid_size=10, render_mode=None):
        super(SnakeEnv, self).__init__()

        self.grid_size = grid_size
        self.window_size = grid_size * 20
        self.render_mode = render_mode

        # Initialize Pygame if human rendering is required
        if self.render_mode == 'human':
            pygame.init()
            self.screen = pygame.display.set_mode((self.window_size, self.window_size))
            self.clock = pygame.time.Clock()

        # Action space: 0=UP, 1=RIGHT, 2=DOWN, 3=LEFT
        self.action_space = spaces.Discrete(4)

        # Observation space: [head_x, head_y, food_x, food_y]
        self.observation_space = spaces.Box(
            low=0, high=1,
            shape=(4,),  # Changed from 8 to 4
            dtype=np.float32
        )

    def reset(self, *, seed=None, options=None):
        if seed is not None:
            np.random.seed(seed)
            random.seed(seed)

        # Initialize snake in the middle
        self.snake = [(self.grid_size//2, self.grid_size//2)]
        self.direction = 1  # Start moving right
        self.food = self._place_food()
        self.steps = 0
        self.score = 0

        return self._get_obs(), {}

    def _place_food(self):
        while True:
            food = (random.randint(0, self.grid_size-1),
                   random.randint(0, self.grid_size-1))
            if food not in self.snake:
                return food

    def _get_obs(self):
        head = self.snake[0]
        return np.array([
            head[0] / self.grid_size,  # head x position
            head[1] / self.grid_size,  # head y position
            self.food[0] / self.grid_size,  # food x position
            self.food[1] / self.grid_size,  # food y position
        ], dtype=np.float32)

    def step(self, action):
        self.steps += 1
        reward = 0
        done = False

        # Update direction based on action
        self.direction = action

        # Get new head position
        head = self.snake[0]
        if action == 0:  # UP
            new_head = (head[0], head[1] - 1)
        elif action == 1:  # RIGHT
            new_head = (head[0] + 1, head[1])
        elif action == 2:  # DOWN
            new_head = (head[0], head[1] + 1)
        else:  # LEFT
            new_head = (head[0] - 1, head[1])

        # Check for collision with walls or self
        if (new_head[0] < 0 or new_head[0] >= self.grid_size or
            new_head[1] < 0 or new_head[1] >= self.grid_size or
            new_head in self.snake):
            return self._get_obs(), -10, True, False, {}

        # Move snake
        self.snake.insert(0, new_head)

        # Check if food is eaten
        if new_head == self.food:
            self.score += 1
            reward = 10
            self.food = self._place_food()
        else:
            self.snake.pop()
            # Small reward/penalty based on distance to food
            prev_dist = abs(head[0] - self.food[0]) + abs(head[1] - self.food[1])
            new_dist = abs(new_head[0] - self.food[0]) + abs(new_head[1] - self.food[1])
            reward = 0.1 if new_dist < prev_dist else -0.1

        # End episode if it's taking too long
        if self.steps >= 100:
            done = True

        return self._get_obs(), reward, done, False, {}

# %%
# Training function
def train_and_evaluate(model_class, env, total_timesteps, model_name):
    model = model_class("MlpPolicy", env, verbose=1)
    model.learn(total_timesteps=total_timesteps)

    # Evaluate the model
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
    print(f"{model_name} - Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")

    return model, mean_reward

# %%
def main():
    # Create environment
    env = SnakeEnv(render_mode=None)

    # Training parameters
    total_timesteps = 100000

    # Train DQN
    print("Training DQN...")
    dqn_model = DQN(
        "MlpPolicy",
        env,
        learning_rate=1e-3,
        buffer_size=50000,
        learning_starts=1000,
        batch_size=64,
        gamma=0.99,
        verbose=1
    )

    dqn_model.learn(total_timesteps=total_timesteps)
    mean_reward_dqn, std_reward_dqn = evaluate_policy(dqn_model, env, n_eval_episodes=10)
    print(f"DQN Mean reward: {mean_reward_dqn:.2f} +/- {std_reward_dqn:.2f}")

    # Train PPO
    print("\nTraining PPO...")
    ppo_model = PPO(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        verbose=1
    )

    ppo_model.learn(total_timesteps=total_timesteps)
    mean_reward_ppo, std_reward_ppo = evaluate_policy(ppo_model, env, n_eval_episodes=10)
    print(f"PPO Mean reward: {mean_reward_ppo:.2f} +/- {std_reward_ppo:.2f}")

    # Compare results
    print("\nFinal Comparison:")
    print(f"DQN average reward: {mean_reward_dqn:.2f}")
    print(f"PPO average reward: {mean_reward_ppo:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Training DQN...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.8     |
# |    ep_rew_mean      | -10.1    |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 10252    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 215      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.6     |
# |    ep_rew_mean      | -8.77    |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 9628     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 333      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | -8.48    |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 9781     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 410      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | -8.31    |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 9340     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 459      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.8     |
# |    ep_rew_mean      | -8.68    |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 9768     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 616      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | -8.47    |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 10414    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 802      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | -8.34    |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7822     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1031     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.305    |
# |    n_updates        | 7        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | -7.62    |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 5045     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1121     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.153    |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.1     |
# |    ep_rew_mean      | -7.91    |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3401     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1300     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00485  |
# |    n_updates        | 74       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.7     |
# |    ep_rew_mean      | -7.9     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3175     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1387     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.446    |
# |    n_updates        | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.8     |
# |    ep_rew_mean      | -7.64    |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2937     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1529     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.586    |
# |    n_updates        | 132      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.5     |
# |    ep_rew_mean      | -7.6     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2790     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1656     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.442    |
# |    n_updates        | 163      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.7     |
# |    ep_rew_mean      | -7.61    |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2715     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1752     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.295    |
# |    n_updates        | 187      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | -7.41    |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2584     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1874     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.301    |
# |    n_updates        | 218      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | -7.22    |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2524     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2007     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.595    |
# |    n_updates        | 251      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.4     |
# |    ep_rew_mean      | -7.22    |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2396     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2072     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.733    |
# |    n_updates        | 267      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | -7.09    |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2211     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2272     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00524  |
# |    n_updates        | 317      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.7     |
# |    ep_rew_mean      | -6.96    |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2164     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2426     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.591    |
# |    n_updates        | 356      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.8     |
# |    ep_rew_mean      | -6.69    |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2074     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2642     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00791  |
# |    n_updates        | 410      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.2     |
# |    ep_rew_mean      | -6.73    |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2002     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2817     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.295    |
# |    n_updates        | 454      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35       |
# |    ep_rew_mean      | -6.39    |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1989     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2937     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00172  |
# |    n_updates        | 484      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | -6.3     |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1951     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3136     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.297    |
# |    n_updates        | 533      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | -6.12    |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1953     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3227     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.733    |
# |    n_updates        | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.9     |
# |    ep_rew_mean      | -5.95    |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1925     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3347     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.157    |
# |    n_updates        | 586      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.3     |
# |    ep_rew_mean      | -6       |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1917     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3433     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.154    |
# |    n_updates        | 608      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | -5.78    |
# |    exploration_rate | 0.663    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1895     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3552     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.299    |
# |    n_updates        | 637      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | -5.57    |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1878     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3687     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.593    |
# |    n_updates        | 671      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.2     |
# |    ep_rew_mean      | -5.44    |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1874     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3734     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.582    |
# |    n_updates        | 683      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.2     |
# |    ep_rew_mean      | -5.31    |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1872     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3878     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.578    |
# |    n_updates        | 719      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.9     |
# |    ep_rew_mean      | -5.1     |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1858     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4004     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.729    |
# |    n_updates        | 750      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.5     |
# |    ep_rew_mean      | -4.88    |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1836     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4149     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.149    |
# |    n_updates        | 787      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | -4.57    |
# |    exploration_rate | 0.6      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1831     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4209     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.292    |
# |    n_updates        | 802      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | -4.65    |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1828     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4320     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.297    |
# |    n_updates        | 829      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.1     |
# |    ep_rew_mean      | -4.42    |
# |    exploration_rate | 0.581    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1813     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4408     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.594    |
# |    n_updates        | 851      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | -4.18    |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1792     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4585     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.456    |
# |    n_updates        | 896      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | -4.27    |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1789     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4687     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.3      |
# |    n_updates        | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31       |
# |    ep_rew_mean      | -3.96    |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1779     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4756     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.3      |
# |    n_updates        | 938      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.5     |
# |    ep_rew_mean      | -3.74    |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1777     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4899     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.722    |
# |    n_updates        | 974      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31       |
# |    ep_rew_mean      | -3.53    |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1764     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4976     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.153    |
# |    n_updates        | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.5     |
# |    ep_rew_mean      | -3.43    |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1741     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5155     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.154    |
# |    n_updates        | 1038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | -3.09    |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1728     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5336     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.148    |
# |    n_updates        | 1083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.5     |
# |    ep_rew_mean      | -2.67    |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1726     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5422     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.588    |
# |    n_updates        | 1105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.4     |
# |    ep_rew_mean      | -2.66    |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1727     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5569     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.571    |
# |    n_updates        | 1142     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | -2.56    |
# |    exploration_rate | 0.465    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1719     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5635     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.275    |
# |    n_updates        | 1158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | -2.35    |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1715     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5689     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.161    |
# |    n_updates        | 1172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.6     |
# |    ep_rew_mean      | -2.44    |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1712     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5797     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.724    |
# |    n_updates        | 1199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | -2.44    |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1707     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5896     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.594    |
# |    n_updates        | 1223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.4     |
# |    ep_rew_mean      | -2.34    |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1699     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5971     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.442    |
# |    n_updates        | 1242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27       |
# |    ep_rew_mean      | -2.24    |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1704     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6048     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.155    |
# |    n_updates        | 1261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.9     |
# |    ep_rew_mean      | -2.05    |
# |    exploration_rate | 0.418    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1694     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6124     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.302    |
# |    n_updates        | 1280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.5     |
# |    ep_rew_mean      | -1.74    |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1691     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6201     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.739    |
# |    n_updates        | 1300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | -1.74    |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1687     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6229     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.297    |
# |    n_updates        | 1307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26       |
# |    ep_rew_mean      | -1.42    |
# |    exploration_rate | 0.399    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1669     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6331     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.704    |
# |    n_updates        | 1332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.2     |
# |    ep_rew_mean      | -1.32    |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1660     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6398     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.449    |
# |    n_updates        | 1349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | -1.22    |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1647     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6480     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.278    |
# |    n_updates        | 1369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | -1.31    |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1632     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6562     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.304    |
# |    n_updates        | 1390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | -1.31    |
# |    exploration_rate | 0.368    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1620     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6654     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.448    |
# |    n_updates        | 1413     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | -1.11    |
# |    exploration_rate | 0.363    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1610     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6701     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.575    |
# |    n_updates        | 1425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | -1.21    |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1589     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6831     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.578    |
# |    n_updates        | 1457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | -1.11    |
# |    exploration_rate | 0.343    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1576     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6921     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.133    |
# |    n_updates        | 1480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1574     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7052     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.686    |
# |    n_updates        | 1512     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | -1.1     |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1572     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7118     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.449    |
# |    n_updates        | 1529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | -0.992   |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1569     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7196     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.04     |
# |    n_updates        | 1548     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | -1.19    |
# |    exploration_rate | 0.305    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1568     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7321     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.722    |
# |    n_updates        | 1580     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | -1.29    |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1566     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7389     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.446    |
# |    n_updates        | 1597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | -1.43    |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1562     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7452     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.84     |
# |    n_updates        | 1612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | -1.62    |
# |    exploration_rate | 0.284    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1559     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7534     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.586    |
# |    n_updates        | 1633     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | -1.32    |
# |    exploration_rate | 0.267    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1555     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7721     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.439    |
# |    n_updates        | 1680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | -1.42    |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1554     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7806     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.608    |
# |    n_updates        | 1701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | -1.42    |
# |    exploration_rate | 0.252    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1554     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7870     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.27     |
# |    n_updates        | 1717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | -1.52    |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1552     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8023     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.435    |
# |    n_updates        | 1755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | -1.22    |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1553     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8129     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.581    |
# |    n_updates        | 1782     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | -1.11    |
# |    exploration_rate | 0.215    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1550     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8258     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.15     |
# |    n_updates        | 1814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | -1.12    |
# |    exploration_rate | 0.213    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1547     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8289     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.433    |
# |    n_updates        | 1822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | -0.699   |
# |    exploration_rate | 0.208    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1546     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8341     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.569    |
# |    n_updates        | 1835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | -0.805   |
# |    exploration_rate | 0.204    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1545     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8381     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.256    |
# |    n_updates        | 1845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | -0.897   |
# |    exploration_rate | 0.197    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1546     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8450     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.153    |
# |    n_updates        | 1862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | -1.01    |
# |    exploration_rate | 0.192    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1542     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8501     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.974    |
# |    n_updates        | 1875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | -0.915   |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1541     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8541     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.465    |
# |    n_updates        | 1885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | -0.808   |
# |    exploration_rate | 0.18     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1537     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8629     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.576    |
# |    n_updates        | 1907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | -0.498   |
# |    exploration_rate | 0.174    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1531     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8690     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.131    |
# |    n_updates        | 1922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | -0.497   |
# |    exploration_rate | 0.166    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1512     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8781     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00516  |
# |    n_updates        | 1945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | -0.377   |
# |    exploration_rate | 0.16     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1508     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8843     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.295    |
# |    n_updates        | 1960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | -0.073   |
# |    exploration_rate | 0.155    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1503     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8890     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.708    |
# |    n_updates        | 1972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | -0.065   |
# |    exploration_rate | 0.151    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1501     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8934     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.56     |
# |    n_updates        | 1983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 0.149    |
# |    exploration_rate | 0.137    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1489     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9081     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.438    |
# |    n_updates        | 2020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 0.145    |
# |    exploration_rate | 0.13     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1487     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9153     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.592    |
# |    n_updates        | 2038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 0.039    |
# |    exploration_rate | 0.116    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1474     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9310     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.85     |
# |    n_updates        | 2077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 0.463    |
# |    exploration_rate | 0.108    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1470     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9393     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.747    |
# |    n_updates        | 2098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 0.667    |
# |    exploration_rate | 0.0917   |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1461     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9561     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.166    |
# |    n_updates        | 2140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.0792   |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1452     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9693     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.867    |
# |    n_updates        | 2173     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.0741   |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1440     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9746     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.532    |
# |    n_updates        | 2186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 1.72     |
# |    exploration_rate | 0.0669   |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1418     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9822     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# ...
# |    iterations           | 32           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0049318387 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.0137       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.2         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00521     |
# |    value_loss           | 64.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.6       |
# |    ep_rew_mean          | 7.07       |
# | time/                   |            |
# |    fps                  | 835        |
# |    iterations           | 33         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00687081 |
# |    clip_fraction        | 0.0521     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.598     |
# |    explained_variance   | 0.0165     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 44.1       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00373   |
# |    value_loss           | 74.7       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.8         |
# |    ep_rew_mean          | 11           |
# | time/                   |              |
# |    fps                  | 835          |
# |    iterations           | 34           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0061345403 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | 0.0357       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.5         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00445     |
# |    value_loss           | 75           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.2         |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 35           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0032600034 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.0426       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.5         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00607     |
# |    value_loss           | 105          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.1         |
# |    ep_rew_mean          | 11.7         |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 36           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0026808241 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.0105       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.2         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00549     |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.4         |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 37           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0042138593 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.0218       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.3         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 105          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.6        |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 38          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.003913451 |
# |    clip_fraction        | 0.0388      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | 0.0318      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.6        |
# |    ep_rew_mean          | 16          |
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 39          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002965307 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.393      |
# |    explained_variance   | 0.0154      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 138         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.6        |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 40          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.002617745 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | 0.0366      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 150         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.2         |
# |    ep_rew_mean          | 17.3         |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 41           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0059615457 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.373       |
# |    explained_variance   | 0.0182       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.4         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 142          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.6         |
# |    ep_rew_mean          | 19.5         |
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 42           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0056645228 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 0.0516       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.7         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 143          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.8         |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 43           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0011116874 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.334       |
# |    explained_variance   | 0.0441       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.5         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000866    |
# |    value_loss           | 137          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.4         |
# |    ep_rew_mean          | 17.7         |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 44           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0018885513 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.324       |
# |    explained_variance   | 0.00594      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.6         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 150          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.9         |
# |    ep_rew_mean          | 22.1         |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 45           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0024682716 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.321       |
# |    explained_variance   | 0.036        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.6         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 135          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | 21.2        |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 46          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.002584147 |
# |    clip_fraction        | 0.0285      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.314      |
# |    explained_variance   | 0.021       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94          |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 177         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.8         |
# |    ep_rew_mean          | 24.4         |
# | time/                   |              |
# |    fps                  | 851          |
# |    iterations           | 47           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0027907616 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.302       |
# |    explained_variance   | 0.0361       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 73.1         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 157          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.6         |
# |    ep_rew_mean          | 26.9         |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 48           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0027538196 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | 0.0405       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.1         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000593    |
# |    value_loss           | 157          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.2         |
# |    ep_rew_mean          | 23.2         |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 49           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0037553625 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.286       |
# |    explained_variance   | 0.0374       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.2         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 152          |
# ------------------------------------------
# PPO Mean reward: 25.88 +/- 35.87
#
# Final Comparison:
# DQN average reward: 13.95
# PPO average reward: 25.88

# %%
# Save DQN model
dqn_model.save("dqn_snake_model")

# Save PPO model
ppo_model.save("ppo_snake_model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Save DQN model
# ----> 2 dqn_model.save("dqn_snake_model")
#       4 # Save PPO model
#       5 ppo_model.save("ppo_snake_model")
#
# NameError: name 'dqn_model' is not defined

# %%
dqn_model = DQN.load("snake_dqn_model")
ppo_model = PPO.load("snake_ppo_model")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dqn_model = DQN.load("snake_dqn_model")
#       2 ppo_model = PPO.load("snake_ppo_model")
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\base_class.py:680, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     677     print("== CURRENT SYSTEM INFO ==")
#     678     get_system_info()
# --> 680 data, params, pytorch_variables = load_from_zip_file(
#     681     path,
#     682     device=device,
#     683     custom_objects=custom_objects,
#     684     print_system_info=print_system_info,
#     685 )
#     687 assert data is not None, "No data found in the saved file"
#     688 assert params is not None, "No params found in the saved file"
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\save_util.py:403, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     376 def load_from_zip_file(
#     377     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     378     load_data: bool = True,
#    (...)
#     382     print_system_info: bool = False,
#     383 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     384     """
#     385     Load model data from a .zip archive
#     386
#    (...)
#     401         and dict of pytorch variables
#     402     """
# --> 403     file = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     405     # set device to cpu if cuda is not available
#     406     device = get_device(device=device)
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\functools.py:877, in singledispatch.<locals>.wrapper(*args, **kw)
#     873 if not args:
#     874     raise TypeError(f'{funcname} requires at least '
#     875                     '1 positional argument')
# --> 877 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\save_util.py:240, in open_path_str(path, mode, verbose, suffix)
#     225 @open_path.register(str)
#     226 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     227     """
#     228     Open a path given by a string. If writing to the path, the function ensures
#     229     that the path exists.
#    (...)
#     238     :return:
#     239     """
# --> 240     return open_path_pathlib(pathlib.Path(path), mode, verbose, suffix)
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\save_util.py:291, in open_path_pathlib(path, mode, verbose, suffix)
#     285         path.parent.mkdir(exist_ok=True, parents=True)
#     287 # if opening was successful uses the open_path() function
#     288 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     289 #   with corrections
#     290 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 291 return open_path_pathlib(path, mode, verbose, suffix)
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\save_util.py:272, in open_path_pathlib(path, mode, verbose, suffix)
#     270             path, suffix = newpath, None
#     271         else:
# --> 272             raise error
#     273 else:
#     274     try:
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\save_util.py:264, in open_path_pathlib(path, mode, verbose, suffix)
#     262 if mode == "r":
#     263     try:
# --> 264         return open_path(path.open("rb"), mode, verbose, suffix)
#     265     except FileNotFoundError as error:
#     266         if suffix is not None and suffix != "":
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\pathlib.py:1241, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1235 def open(self, mode='r', buffering=-1, encoding=None,
#    1236          errors=None, newline=None):
#    1237     """
#    1238     Open the file pointed by this path and return a file object, as
#    1239     the built-in open() function does.
#    1240     """
# -> 1241     return io.open(self, mode, buffering, encoding, errors, newline,
#    1242                    opener=self._opener)
#
# File c:\Users\proah\AppData\Local\Programs\Python\Python39\lib\pathlib.py:1109, in Path._opener(self, name, flags, mode)
#    1107 def _opener(self, name, flags, mode=0o666):
#    1108     # A stub for the opener argument to built-in open()
# -> 1109     return self._accessor.open(self, flags, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'snake_dqn_model.zip'
